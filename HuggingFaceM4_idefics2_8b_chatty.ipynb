# %%
import requests
import torch
from PIL import Image
from transformers import AutoProcessor, AutoModelForVision2Seq
from transformers.image_utils import load_image

# Device configuration
DEVICE = "cuda:0" if torch.cuda.is_available() else "cpu"
# Switch to 16-bit precision (mixed precision)
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

# Note that passing the image urls (instead of the actual pil images) to the processor is also possible


processor = AutoProcessor.from_pretrained("HuggingFaceM4/idefics2-8b-chatty")
model = AutoModelForVision2Seq.from_pretrained(
    "HuggingFaceM4/idefics2-8b-chatty",
    torch_dtype=torch_dtype,
).to(DEVICE)

# Create inputs one image at a time to avoid OutOfMemoryError
def generate_caption(image, prompt):
    inputs = processor(text=prompt, images=[image], return_tensors="pt")
    inputs = {k: v.to(DEVICE) for k, v in inputs.items()}

    generated_ids = model.generate(**inputs, max_new_tokens=2000)
    generated_texts = processor.batch_decode(generated_ids, skip_special_tokens=True)

    return generated_texts[0]
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# processor_config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.64k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/92.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.04k [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/684 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/74.4k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/7 [00:00<?, ?it/s]
# model-00001-of-00007.safetensors:   0%|          | 0.00/4.64G [00:00<?, ?B/s]
# model-00002-of-00007.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00003-of-00007.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# model-00004-of-00007.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00005-of-00007.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00006-of-00007.safetensors:   0%|          | 0.00/4.83G [00:00<?, ?B/s]
# model-00007-of-00007.safetensors:   0%|          | 0.00/4.25G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]

# %%
image1 = load_image("https://i.postimg.cc/Z5DMkRCM/fin-du-ticket-de-caisse-comment-faire-pour-rendre-mon-article-1475620.jpg")
messages1 = [
    {
        "role": "user",
        "content": [
            {"type": "image"},
            {"type": "text", "text": " convert this purchase receipt to json file"},
        ]
    }
]
prompt1 = processor.apply_chat_template(messages1, add_generation_prompt=True)
caption1 = generate_caption(image1, prompt1)



print(caption1)
# Out:
# No chat template is defined for this tokenizer - using the default template for the LlamaTokenizerFast class. If the default is not appropriate for your model, please set `tokenizer.chat_template` to an appropriate template. See https://huggingface.co/docs/transformers/main/chat_templating for more information.
#
# The `seen_tokens` attribute is deprecated and will be removed in v4.41. Use the `cache_position` model input instead.
# User:  convert this purchase receipt to json file
# Assistant: {
#   "receipt": {
#     "total": 41.83,
#     "lines": [
#       {
#         "item": "Lait 1/2",
#         "price": 6.30,
#         "quantity": 1
#       },
#       {
#         "item": "EPINARD SPR 750G",
#         "price": 2.06,
#         "quantity": 1
#       },
#       {
#         "item": "POIREUX RONDEL SUR N.",
#         "price": 1.20,
#         "quantity": 1
#       },
#       {
#         "item": "POT VAPEUR SAUTÉES 2KGS BOX M.R.",
#         "price": 1.83,
#         "quantity": 1
#       },
#       {
#         "item": "MACHE 125G NOTRE DAME",
#         "price": 1.19,
#         "quantity": 1
#       },
#       {
#         "item": "SPEC. POM/RHUBARBE SSA 4X97G",
#         "price": 1.20,
#         "quantity": 1
#       },
#       {
#         "item": "SPAGHETTI BIO COMPLETS 500G",
#         "price": 0.99,
#         "quantity": 1
#       },
#       {
#         "item": "TORSADES BIO SÉMI COMPLETS 500G",
#         "price": 0.99,
#         "quantity": 1
#       },
#       {
#         "item": "BIERE BLANCHE DE NAMUR 33CL",
#         "price": 1.59,
#         "quantity": 1
#       },
#       {
#         "item": "Goudale IPA BLOC 50CL",
#         "price": 2.31,
#         "quantity": 1
#       },
#       {
#         "item": "PIZZA 4 SAISONS 400G J.BIO",
#         "price": 9.98,
#         "quantity": 1
#       },
#       {
#         "item": "DELICIEUX DUOES GELÉE 2.04KG",
#         "price": 6.30,
#         "quantity": 1
#       },
#       {
#         "item": "CRÈME SEMI-EPISSE 18MG 3X20CL",
#         "price": 2.12,
#         "quantity": 1
#       }
#     ]
#   }
# }.

# %%
image1 = load_image("https://i.postimg.cc/3NmsYDkB/the-10-best-star-wars-memes.webp")
messages1 = [
    {
        "role": "user",
        "content": [
            {"type": "image"},
            {"type": "text", "text": " explain this meme to me "},
        ]
    }
]
prompt1 = processor.apply_chat_template(messages1, add_generation_prompt=True)
caption1 = generate_caption(image1, prompt1)



print(caption1)
# Out:
# User:  explain this meme to me
# Assistant: This image is a humorous meme that uses a scene from the movie "Star Wars: The Empire Strikes Back" to make a point about the dangers of technology. The meme features two characters from the movie, Luke Skywalker and Obi-Wan Kenobi, who are sitting in a cave. Luke is holding a lightsaber, while Obi-Wan is holding a cane. The text on the image reads "Handed the most dangerous weapon in the galaxy immediately point at face" and "IMMEDIATELY POINT AT FACE". This meme is a playful commentary on the potential dangers of technology, suggesting that even the most powerful tools can be misused or used inappropriately.

# %%
image1 = load_image("https://i.postimg.cc/65DKstTz/5b0b98f7d2ac3573520ce58b8f5f198c.jpg")
messages1 = [
    {
        "role": "user",
        "content": [
            {"type": "image"},
            {"type": "text", "text": " explain this meme to me "},
        ]
    }
]
prompt1 = processor.apply_chat_template(messages1, add_generation_prompt=True)
caption1 = generate_caption(image1, prompt1)



print(caption1)
# Out:
# User:  explain this meme to me
# Assistant: This image is a meme that features a scene from the movie "Star Wars: The Empire Strikes Back." The main characters, Luke Skywalker and Han Solo, are seen in a cockpit of a ship. Luke is looking at a map, while Han is looking at the ship's control panel. The text overlaid on the image reads:
#
# 1. "Vader's on that ship. How do you know?"
# 2. "I can hear his theme music."
#
# The meme seems to be a humorous take on the idea of being able to sense danger or anticipate events based on one's intuition or hearing. It plays off the iconic theme music from the Star Wars franchise, suggesting that the character can hear the music and thus knows that Darth Vader is on the ship. This meme is likely to resonate with fans of the Star Wars series and those who appreciate a touch of humor in their pop culture references.

# %%
image1 = load_image("https://i.postimg.cc/R0tQP1yX/1614340316-406009.png")
messages1 = [
    {
        "role": "user",
        "content": [
            {"type": "image"},
            {"type": "text", "text": " what are the differences between the two images ? "},
        ]
    }
]
prompt1 = processor.apply_chat_template(messages1, add_generation_prompt=True)
caption1 = generate_caption(image1, prompt1)



print(caption1)
# Out:
# User:  what are the differences between the two images ?
# Assistant: The differences between the two images are the presence of a bottle and a fish in the first image, while the second image features a toy boat and a fish. Additionally, the girl is holding a ball in the first image, and in the second image, she is holding a toy boat.

# %%
image1 = load_image("https://i.postimg.cc/sgXTJh3N/20af5-16473128771869-1920.webp")
messages1 = [
    {
        "role": "user",
        "content": [
            {"type": "image"},
            {"type": "text", "text": " explain this meme to me "},
        ]
    }
]
prompt1 = processor.apply_chat_template(messages1, add_generation_prompt=True)
caption1 = generate_caption(image1, prompt1)



print(caption1)
# Out:
# User:  explain this meme to me
# Assistant: The image is a humorous meme that uses a creative blend of text and visuals to convey a message. It features three people standing on a street, with the focus on two of them. The person on the left is a woman wearing a red dress, and the person on the right is a man wearing a blue shirt. The man is looking at the woman, and she is looking back at him.
#
# The meme adds two additional text elements to the image. The text "ME" is placed over the man's head, and "PEOPLE" is placed over the woman's head. This suggests that the man is thinking about the woman as a person, and the woman is also thinking about the man as a person.
#
# The background of the image is blurred, which draws attention to the two people in focus. The overall composition of the meme suggests a playful and lighthearted interaction between the two individuals.
